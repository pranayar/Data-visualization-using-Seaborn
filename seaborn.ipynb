# %% [markdown]
# <a href="https://colab.research.google.com/github/pranayar/Data-visualization-using-Seaborn/blob/main/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Bar plot
import seaborn as sns

# Load the tips dataset
tips = sns.load_dataset("tips")

# Plot the total bill amount for each day
sns.barplot(x="day", y="total_bill", data=tips)

# %%
# Line plot
import seaborn as sns

# Load the flights dataset
flights = sns.load_dataset("flights")

# Plot the number of passengers over time
sns.lineplot(x="year", y="passengers", data=flights)

# %%
# Scatter plot
import seaborn as sns

# Load the iris dataset
iris = sns.load_dataset("iris")

# Plot sepal length vs sepal width
sns.scatterplot(x="sepal_length", y="sepal_width", data=iris)

# %%
# Box plot
import seaborn as sns

# Load the tips dataset
tips = sns.load_dataset("tips")

# Plot the total bill amount for each day
sns.boxplot(x="day", y="total_bill", data=tips)

# %%
# Heatmap
import seaborn as sns

# Load the flights dataset
flights = sns.load_dataset("flights")

# Create a pivot table showing the average number of passengers for each month and year
pivot = flights.pivot_table(index="month", columns="year", values="passengers")

# Draw a heatmap with the pivot table values
sns.heatmap(pivot)
